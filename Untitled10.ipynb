# %%
1. Tipe data & Operator Python
#Bagaimana cara print
print("Hello, World!")
ketik seperti diatas, lalu klik ctrl+enter maka hasilnya = Hello, World

#Aturan penulisan variabel
Nama variabel boleh diawali menggunakan huruf atau garis bawah _. Contoh: nama, _nama, namaKu, nama_variabel
Karakter selanjutnya dapat berupa huruf, garis bawah _ atau angka. Contoh: __nama, n2, nilai1
Variabel tidak boleh dimulai dengan angka ataupun simbol.
Variabel tidak boleh berupa kata kunci (keyword) yang ada dalam Python. Contoh: if, else, while, for, dan masih banyak lagi
#Variabel
Nama = "Rendika"
umur = 50
status_pernikahan = "Belum Menikah"
statuspernikahan = "Menikah"

#Percabangan
nilai = int(input("Masukkan nilaimu: "))

if nilai >= 70:
    print("Selamat anda lulus MatKul Algoritma & Pemrograman!")
elif nilai == 20:
    print('Semoga Lulus')
else:
    print("Maaf anda tidak lulus")
Note: jika if tidak memenuhi syarat maka ia akan terus turun ke elif dan selanjutnya.

#Looping dan While
for i in range(1,5):
    print(i)
    print('Namaku',i)
Note: Hasil akan muncul semakin kebawah

2. Ekspresi Persamaan Matematika
#Penjumlahan
# Input bilangan dari pengguna
bilangan1 = float(input("Masukkan bilangan pertama: "))
bilangan2 = float(input("Masukkan bilangan kedua: "))
# Hitung penjumlahan
hasil = bilangan1 + bilangan2
# Cetak hasil
print("Hasil penjumlahan:", hasil)
Note: Semisal kita memasukkan angka 10 di kedua bilangan maka hasil saat print adalah 20

#Pangkat
# Input basis dan eksponen dari pengguna
basis = float(input("Masukkan basis: "))
eksponen = float(input("Masukkan eksponen: "))
# Hitung hasil pangkat
hasil = basis ** eksponen
# Cetak hasil
print("Hasil pangkat:", hasil)
Note: Semisal kita memasukkan angka 5 sebagai angka dan 2 sebagai pangkat maka hasil saat di print adalah 25

3. Percabangan If Else
#Percabangan If (single alternative selection)
umur = 20
if umur >= 18:
    print("Anda sudah dewasa.")
Hasil = Anda sudah dewasa

#Percabangan If, Else (dual alternative selection)
nilai = 70
if nilai >= 60:
    print("Anda lulus.")
else:
    print("Anda belum lulus.")
Hasil = Anda lulus

#Percabangan If, Elif, Else (multiple alternative selection)
nilai = 75
if nilai >= 90:
    print("A")
elif nilai >= 80:
    print("B")
elif nilai >= 70:
    print("C")
else:
    print("D")
Hasil = C

4. Nested If & Dasar Perluangan
#Nested If
if conditionA:
    Code here executes when 'conditionA' is True
else:
    Code that runs when 'conditionA' is False
    if conditionB:
        Code that runs when 'conditionA' is False
        and 'conditionB' is True
        
#Nested if dalam "Menentukan suatu angka positif, negatif atau 0"
number = int(input('Enter the number you want to check: '))
# outer if statement
if (number >= 0):
    # inner if statement
    if number == 0:
        print('Number is 0')
    # inner else statement
    elif number == 7:
        print('Number is 7')
    else: 
        print('Number is positive')
# outer else statement
else:
    print('Number is negative')
Hasil = 
Masukkan Angka yang ingin anda cek: 10
Number is positive

5. Format panggilan fungsi
# Tanpa function kita perlu lakukan ini

print('Halo Nurul, selamat datang!')
print('Halo Lendis, selamat datang!')
print('Halo Fabri, selamat datang!')
print('Halo Isa, selamat datang!')
